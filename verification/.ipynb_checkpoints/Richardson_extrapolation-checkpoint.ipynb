# %%
import pyvista
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Get data from OF

# %%
points = np.arange(0.01, 0.2, 0.01)

pyVista_res_l2 = pd.DataFrame()
pyVista_res_l2['points'] = points
pyVista_res_l2.set_index('points', inplace = True)

pyVista_sum_l2 = pd.DataFrame()
pyVista_sum_l2['points'] = points
pyVista_sum_l2.set_index('points', inplace = True)

# %%
filename = 'data/ri_extr/channel_57k_cells.vtk'
mesh = pyvista.read(filename)
for i in range(1,1000):
    print(mesh.sample_over_line((0, -0.00227, 0.15),(0, 0.00227, 0.015),resolution = i)['U'].max())
# Out:
# 3.700966e-18
# 1.05854
# 0.9410026
# 1.05854
# 1.0136276
# 1.05854
# 1.0375625
# 1.05854
# 1.0422512
# 1.05854
# 1.0452331
# 1.05854
# 1.0472896
# 1.05854
# 1.0487974
# 1.05854
# 1.0499489
# 1.05854
# 1.0508561
# 1.05854
# 1.0515901
# 1.05854
# 1.0521963
# 1.05854
# 1.0527054
# 1.05854
# 1.0531391
# 1.05854
# 1.0535129
# 1.05854
# 1.0538385
# 1.05854
# 1.0541238
# 1.05854
# 1.0543764
# 1.05854
# 1.0546017
# 1.05854
# 1.0548038
# 1.05854
# 1.0549862
# 1.05854
# 1.0551516
# 1.05854
# 1.0553024
# 1.05854
# 1.0554403
# 1.05854
# 1.0555669
# 1.05854
# 1.0556836
# 1.05854
# 1.0557915
# 1.05854
# 1.0558915
# 1.05854
# 1.0559845
# 1.05854
# 1.0560713
# 1.05854
# 1.0561522
# 1.05854
# 1.0562282
# 1.05854
# 1.0562993
# 1.05854
# 1.0563663
# 1.05854
# 1.0564294
# 1.05854
# 1.0564889
# 1.05854
# 1.0565451
# 1.05854
# 1.0565984
# 1.05854
# 1.0566489
# 1.05854
# 1.0566968
# 1.05854
# 1.0567423
# 1.05854
# 1.0567857
# 1.05854
# 1.0568271
# 1.05854
# 1.0568664
# 1.05854
# 1.0569041
# 1.05854
# ...

# %%
res.get_array('U').max()
# Out:
# 1.05854

# %%
size =31# 57601
plt.plot(np.linspace(-0.00227, 0.00227, size), res['U'][:,-1])

# %%
mesh['U'][:,-1]
# Out:
# array([0.523871 , 0.522691 , 0.522269 , ..., 0.421761 , 0.269326 ,
#        0.0949576], dtype=float32)

# %%
len(mesh['U'].flatten())
# Out:
# 172800

# %%
res['U'].shape
# Out:
# (57601, 3)

# %%
res['U']
# Out:
# array([[ 6.61060864e-28, -1.06509349e-22, -2.43538087e-15],
#        [-1.79446660e-17,  2.89122350e-12,  6.61090307e-05],
#        [-3.58363990e-17,  5.77391867e-12,  1.32023051e-04],
#        ...,
#        [ 3.96521186e-18, -5.77394512e-12,  1.32023051e-04],
#        [ 1.98553456e-18, -2.89123695e-12,  6.61090307e-05],
#        [-7.17902785e-29,  1.04537436e-22, -2.39028103e-15]], dtype=float32)

# %%
def get_sample_data(path):
    filename = path + '.vtk'
    mesh = pyvista.read(filename)
    mesh.sample_over_line((0, -0.00227, 0.09),(0, 0.00227, 0.09))
    sample = [] 
    for i in points:
         sample.append(mesh.sample_over_line((0, -0.00227, i),(0, 0.00227, i))['U'].max())#resolution=15
    sums=[] 
    for i in points:
         sums.append(mesh.sample_over_line((0, -0.00227, i),(0, 0.00227, i))['U'].sum())#resolution=15
    return sample, sums

# %%
files = ['16k_cells_2']#['57k_cells','194k_cells','460k_cells','656k_cells']
for i in files:
    pyVista_res_l2[i], pyVista_sum_l2[i]  = get_sample_data('data/ri_extr/'+'channel_'+i)

# %%
pyVista_res_l2
# Out:
#         57k_cells  194k_cells  460k_cells  656k_cells  16k_cells  8k_cells  \
# points
# 0.01     0.858859    0.856453    0.853830    0.852906   0.858651  0.836911
# 0.02     0.971261    0.976364    0.977505    0.977732   0.963256  0.933905
# 0.03     1.019305    1.027007    1.029495    1.030146   1.008348  0.975838
# 0.04     1.040790    1.049365    1.052330    1.053135   1.028950  0.995454
# 0.05     1.050650    1.059507    1.062645    1.063500   1.038520  1.004930
# 0.06     1.055235    1.064175    1.067370    1.068247   1.043055  1.009580
# 0.07     1.057380    1.066333    1.069550    1.070431   1.045205  1.011880
# 0.08     1.058390    1.067335    1.070560    1.071440   1.046235  1.013020
# 0.09     1.058860    1.067800    1.071025    1.071913   1.046720  1.013590
# 0.10     1.059085    1.068015    1.071240    1.072127   1.046960  1.013870
# 0.11     1.059190    1.068120    1.071340    1.072230   1.047070  1.014010
# ...

# %% [markdown]
# ## Analytical solution

# %%
#radius
R = 0.00227 
#density
rho = 1.0
v = 0.5216
#Reynolds number
Re = rho*v*R*2/(1.48e-05)
print(Re)
# Out:
# 160.0043243243243

# %%
length = 0.5
#friction factor
f = 64/Re
dP = f*length*1*v**2/(2*R*2)
pressureGrad = dP/length
dPdx = 1.48e-05*4/(R**2)
print('f = {:2.4}, Pressure Gradient = {:2.8}, dpdx = {:2.8}'.format(f, pressureGrad, dPdx))
# Out:
# f = 0.4, Pressure Gradient = 11.984987, dpdx = 11.488676

# %%
r1 = np.linspace(-0.00227,0.00227,1000)
r = np.sqrt(r1**2)  # array how radius changing
analytical_solution = (R**2-r**2)*(1/(4*1.48e-05))*pressureGrad 

plt.plot(analytical_solution);

# %%
analytical_solution.max()
# Out:
# 1.043198954710466

# %%
v_max = v*2
v_max
# Out:
# 1.0432

# %%
filename = '/home/asa/Desktop/SIR/05lPerMin/2d_case/VTK/2d_case_4000' + '.vtk'
mesh = pyvista.read(filename)
mesh.sample_over_line((0, -0.00227, 0.09),(0, 0.00227, 0.09))
# Out:
# PolyData (0x7f0de4ae3520)
#   N Cells:	1
#   N Points:	6001
#   X Bounds:	0.000e+00, 0.000e+00
#   Y Bounds:	-2.270e-03, 2.270e-03
#   Z Bounds:	9.000e-02, 9.000e-02
#   N Arrays:	11

# %% [markdown]
# import math

# %%
import math
length = 0.2
pi= math.pi

# %%
V_cyl = pi*length*(R**2) # cylindre volume
V_cyl
# Out:
# 3.2376625569365686e-06

# %%
V_cyl/460800
# Out:
# 7.026177423907484e-12

# %%
V_cyl/57600
# Out:
# 5.6209419391259874e-11

# %%
V_cyl/16200
# Out:
# 1.998557133911462e-10

# %%
n_el = np.array([57600, 194400, 460000]) # number of elements for each mesh
A_omega = np.ones(3)*V_cyl
h = np.sqrt(A_omega/n_el) 
h
# Out:
# array([7.49729414e-06, 4.08101002e-06, 2.65299771e-06])

# %%
h[2]/h[1]
# Out:
# 0.6500836066631537

# %%
error = pyVista_res_l2 - analytical_solution.max()
# Out:
#         57k_cells  194k_cells  460k_cells
# points
# 0.01    -0.184339   -0.186745   -0.189369
# 0.02    -0.071938   -0.066834   -0.065694
# 0.03    -0.023894   -0.016191   -0.013704
# 0.04    -0.002409    0.006166    0.009131
# 0.05     0.007451    0.016309    0.019446
# 0.06     0.012036    0.020976    0.024171
# 0.07     0.014181    0.023134    0.026351
# 0.08     0.015191    0.024136    0.027361
# 0.09     0.015661    0.024601    0.027826
# 0.10     0.015886    0.024816    0.028041
# 0.11     0.015991    0.024921    0.028141
# 0.12     0.016041    0.024971    0.028191
# 0.13     0.016061    0.024991    0.028211
# 0.14     0.016071    0.025001    0.028221
# 0.15     0.016081    0.025001    0.028221
# 0.16     0.016081    0.025001    0.028231
# 0.17     0.016081    0.025011    0.028231
# 0.18     0.016081    0.025011    0.028231
# 0.19     0.016081    0.025011    0.028231

# %%
mesh_errors = pd.DataFrame()
mesh_errors['1'] = np.abs(pyVista_res_l2['194k_cells'] - pyVista_res_l2['57k_cells'])
mesh_errors['2'] = np.abs(pyVista_res_l2['460k_cells'] - pyVista_res_l2['194k_cells'])
mesh_errors['3'] = np.abs(pyVista_res_l2['656k_cells'] - pyVista_res_l2['460k_cells'])
mesh_errors
# Out:
#                1         2         3
# points
# 0.01    0.002406  0.002623  0.000924
# 0.02    0.005103  0.001141  0.000227
# 0.03    0.007702  0.002488  0.000651
# 0.04    0.008575  0.002965  0.000805
# 0.05    0.008857  0.003137  0.000855
# 0.06    0.008940  0.003195  0.000877
# 0.07    0.008953  0.003217  0.000881
# 0.08    0.008945  0.003225  0.000880
# 0.09    0.008940  0.003225  0.000888
# 0.10    0.008930  0.003225  0.000888
# 0.11    0.008930  0.003220  0.000890
# 0.12    0.008930  0.003220  0.000880
# 0.13    0.008930  0.003220  0.000884
# 0.14    0.008930  0.003220  0.000883
# 0.15    0.008920  0.003220  0.000890
# 0.16    0.008920  0.003230  0.000880
# 0.17    0.008930  0.003220  0.000880
# 0.18    0.008930  0.003220  0.000880
# 0.19    0.008930  0.003220  0.000880

# %%
plt.plot(pyVista_res_l2['57k_cells'])

# %%
element = pyVista_res_l2['57k_cells'][0.19]
## wrong!!!
l2 = np.sqrt(np.sum((element-analytical_solution.max())**2)/np.sum(analytical_solution**2))

print('l2 norm is:',round(l2,6))
# Out:
# l2 norm is: 0.000668
