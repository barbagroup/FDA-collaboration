# %%
import pyvista
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Get data from OF

# %%
points = np.arange(0.01, 0.2, 0.01)

pyVista_res_l2 = pd.DataFrame()
pyVista_res_l2['points'] = points
pyVista_res_l2.set_index('points', inplace = True)

pyVista_sum_l2 = pd.DataFrame()
pyVista_sum_l2['points'] = points
pyVista_sum_l2.set_index('points', inplace = True)

# %%
#how we getting 3ed column of velocity field
#mesh['U'][:,-1]

# %%
def get_sample_data(path):
    filename = path + '.vtk'
    mesh = pyvista.read(filename)
    mesh.sample_over_line((0, -0.00227, 0.09),(0, 0.00227, 0.09))
    sample = [] 
    for i in points:
         sample.append(mesh.sample_over_line((0, -0.00227, i),(0, 0.00227, i), resolution=30)['U'].max())#resolution=15
    sums=[] 
    for i in points:
         sums.append(mesh.sample_over_line((0, -0.00227, i),(0, 0.00227, i),resolution=30)['U'].sum())#resolution=15
    return sample, sums

# %%
files = ['8k_cells','16k_cells','57k_cells','194k_cells','460k_cells','656k_cells']

#/home/asa/Desktop/OldReposOfFDA_collab/FDA-collaboration/verification/
for i in files:
    pyVista_res_l2[i], pyVista_sum_l2[i]  = get_sample_data('data/ri_extr/'+'channel_'+i)

# %%
pyVista_res_l2
# Out:
#         8k_cells  16k_cells  57k_cells  194k_cells  460k_cells  656k_cells
# points
# 0.01    0.836911   0.858651   0.858859    0.856453    0.853830    0.852906
# 0.02    0.933905   0.963256   0.971261    0.976364    0.977505    0.977732
# 0.03    0.975838   1.008348   1.019305    1.027007    1.029495    1.030146
# 0.04    0.995454   1.028950   1.040790    1.049365    1.052330    1.053135
# 0.05    1.004930   1.038520   1.050650    1.059507    1.062645    1.063500
# 0.06    1.009580   1.043055   1.055235    1.064175    1.067370    1.068247
# 0.07    1.011880   1.045205   1.057380    1.066333    1.069550    1.070431
# 0.08    1.013020   1.046235   1.058390    1.067335    1.070560    1.071440
# 0.09    1.013590   1.046720   1.058860    1.067800    1.071025    1.071913
# 0.10    1.013870   1.046960   1.059085    1.068015    1.071240    1.072127
# 0.11    1.014010   1.047070   1.059190    1.068120    1.071340    1.072230
# 0.12    1.014075   1.047120   1.059240    1.068170    1.071390    1.072270
# 0.13    1.014115   1.047148   1.059260    1.068190    1.071410    1.072294
# 0.14    1.014130   1.047160   1.059270    1.068200    1.071420    1.072302
# 0.15    1.014140   1.047160   1.059280    1.068200    1.071420    1.072310
# 0.16    1.014145   1.047170   1.059280    1.068200    1.071430    1.072310
# 0.17    1.014150   1.047170   1.059280    1.068210    1.071430    1.072310
# 0.18    1.014150   1.047170   1.059280    1.068210    1.071430    1.072310
# 0.19    1.014150   1.047170   1.059280    1.068210    1.071430    1.072310

# %%
pyVista_sum_l2
# Out:
#          8k_cells  16k_cells  57k_cells  194k_cells  460k_cells  656k_cells
# points
# 0.01    18.299803  19.064999  19.275368   19.422731   19.453342   19.466373
# 0.02    19.174759  19.978199  20.233908   20.434179   20.492670   20.517771
# 0.03    19.539337  20.351290  20.621946   20.837967   20.905504   20.934532
# 0.04    19.706453  20.518711  20.792809   21.013790   21.084406   21.114872
# 0.05    19.786465  20.596054  20.870934   21.093264   21.164984   21.195986
# 0.06    19.825594  20.632639  20.907194   21.129791   21.201849   21.233078
# 0.07    19.844929  20.649961  20.924179   21.146700   21.218861   21.250156
# 0.08    19.854502  20.658262  20.932137   21.154531   21.226709   21.258060
# 0.09    19.859287  20.662178  20.935871   21.158186   21.230360   21.261717
# 0.10    19.861633  20.664095  20.937660   21.159880   21.232046   21.263397
# 0.11    19.862816  20.664991  20.938463   21.160685   21.232830   21.264189
# 0.12    19.863363  20.665401  20.938868   21.161055   21.233202   21.264534
# 0.13    19.863693  20.665615  20.939043   21.161201   21.233364   21.264711
# 0.14    19.863823  20.665716  20.939135   21.161297   21.233433   21.264780
# 0.15    19.863907  20.665731  20.939177   21.161325   21.233479   21.264820
# 0.16    19.863953  20.665796  20.939177   21.161356   21.233494   21.264841
# 0.17    19.863989  20.665794  20.939177   21.161388   21.233501   21.264845
# 0.18    19.863989  20.665798  20.939177   21.161385   21.233501   21.264864
# 0.19    19.863997  20.665802  20.939177   21.161385   21.233501   21.264858

# %% [markdown]
# ## Analytical solution

# %%
#radius
R = 0.00227 
#density
rho = 1.0
v = 0.5216
#Reynolds number
Re = rho*v*R*2/(1.48e-05)
print(Re)
# Out:
# 160.0043243243243

# %%
length = 0.5
#friction factor
f = 64/Re
dP = f*length*1*v**2/(2*R*2)
pressureGrad = dP/length
dPdx = 1.48e-05*4/(R**2)
print('f = {:2.4}, Pressure Gradient = {:2.8}, dpdx = {:2.8}'.format(f, pressureGrad, dPdx))
# Out:
# f = 0.4, Pressure Gradient = 11.984987, dpdx = 11.488676

# %%
plt.figure(figsize=(15,6))
r1 = np.linspace(-0.00227,0.00227,31)#,1000)
r = np.sqrt(r1**2)  # array how radius changing
analytical_solution = (R**2-r**2)*(1/(4*1.48e-05))*pressureGrad 
plt.title('Analytical solution')
plt.plot(analytical_solution);

# %%
analytical_solution.max()
# Out:
# 1.0431999999999997

# %%
v_max = v*2
v_max
# Out:
# 1.0432

# %% [markdown]
# # Gather plot data

# %%
plots = []

#files = ['16k_cells','57k_cells','194k_cells','460k_cells','656k_cells']
for i in files: 
    filename = 'data/ri_extr/channel_'+i+'.vtk'
    mesh = pyvista.read(filename)

    plots.append(mesh.sample_over_line((0, -0.00227, 0.15),(0, 0.00227, 0.015),resolution = 30)['U'][:,-1])

# %%
plt.figure(figsize=(15,6))
x = np.linspace(0,30,1000)

for i in range(0,len(files)):
    
    plt.plot(plots[i], label = files[i])
plt.plot(analytical_solution, label = 'analytical result', color = 'black', linestyle = ':')
plt.legend(loc="upper right");

# %%
import math
length = 0.2
pi = math.pi

# %%
V_cyl = pi*length*(R**2) # cylindre volume
V_cyl
# Out:
# 3.2376625569365686e-06

# %%
V_cyl/460800
# Out:
# 7.026177423907484e-12

# %%
V_cyl/57600
# Out:
# 5.6209419391259874e-11

# %%
V_cyl/16200
# Out:
# 1.998557133911462e-10

# %%
n_el = np.array([8000, 16000, 57600, 194400, 460000, 656000]) # number of elements for each mesh
A_omega = np.ones((len(n_el)))*V_cyl
h = np.sqrt(A_omega/n_el) 
h
# Out:
# array([2.01173512e-05, 1.42251155e-05, 7.49729414e-06, 4.08101002e-06,
#        2.65299771e-06, 2.22158979e-06])

# %%
h[2]/h[1]
# Out:
# 0.5270462766947299

# %%
error = pyVista_res_l2 - analytical_solution.max()

# %%
mesh_errors = pd.DataFrame()
mesh_errors['1'] = np.abs(pyVista_res_l2['16k_cells'] - pyVista_res_l2['8k_cells'])
mesh_errors['2'] = np.abs(pyVista_res_l2['57k_cells'] - pyVista_res_l2['16k_cells'])
mesh_errors['3'] = np.abs(pyVista_res_l2['194k_cells'] - pyVista_res_l2['57k_cells'])
mesh_errors['4'] = np.abs(pyVista_res_l2['460k_cells'] - pyVista_res_l2['194k_cells'])
mesh_errors['5'] = np.abs(pyVista_res_l2['656k_cells'] - pyVista_res_l2['460k_cells'])
mesh_errors.tail()
# Out:
#                1        2        3        4        5
# points
# 0.15    0.033020  0.01212  0.00892  0.00322  0.00089
# 0.16    0.033025  0.01211  0.00892  0.00323  0.00088
# 0.17    0.033020  0.01211  0.00893  0.00322  0.00088
# 0.18    0.033020  0.01211  0.00893  0.00322  0.00088
# 0.19    0.033020  0.01211  0.00893  0.00322  0.00088

# %%
element = pyVista_res_l2['57k_cells'][0.19]

norm = []
for i in range(0,len(files)):
    l2 = np.sqrt(np.sum(((plots[i]-analytical_solution)**2)))
    print('l2 norm for', files[i],'is:',round(l2,8))
    norm.append(l2)
# Out:
# l2 norm for 8k_cells is: 0.18537437
# l2 norm for 16k_cells is: 0.04868362
# l2 norm for 57k_cells is: 0.05638754
# l2 norm for 194k_cells is: 0.09222755
# l2 norm for 460k_cells is: 0.1052424
# l2 norm for 656k_cells is: 0.11180504

# %%
plt.figure(figsize=(12,6))
plt.plot([8,16,57,194,460,656],norm)
plt.xlabel('Number of mesh cells, x1000')
plt.ylabel('l2 norm for max velocity, m/s')
plt.title('Error calculated based on analytic solution')
plt.xticks([8,16,57,194,460,656], ['8','16','57','194', '460','656']);
#fig.set_xticklabels([8,16,57,194,460,656]);

# %%
plt.figure(figsize=(12,6))
plt.plot(norm)
plt.xlabel('Number of mesh cells, x1000')
plt.ylabel('l2 norm for max velocity, m/s')
plt.title('Error calculated based on analytic solution')
plt.xticks([0,1,2,3,4,5], ['8','16','57','194', '460','656']);
#fig.set_xticklabels([8,16,57,194,460,656]);

# %% [markdown]
# # From the plot data we could see that there is no convergence.

# %%
max_error = pd.DataFrame()
max_error['1'] = np.abs(pyVista_res_l2['656k_cells'] - pyVista_res_l2['8k_cells'])
max_error['2'] = np.abs(pyVista_res_l2['656k_cells'] - pyVista_res_l2['16k_cells'])
max_error['3'] = np.abs(pyVista_res_l2['656k_cells'] - pyVista_res_l2['57k_cells'])
max_error['4'] = np.abs(pyVista_res_l2['656k_cells'] - pyVista_res_l2['194k_cells'])
max_error['5'] = np.abs(pyVista_res_l2['656k_cells'] - pyVista_res_l2['460k_cells'])
max_error.tail()
# Out:
#                1        2        3        4        5
# points
# 0.15    0.058170  0.02515  0.01303  0.00411  0.00089
# 0.16    0.058165  0.02514  0.01303  0.00411  0.00088
# 0.17    0.058160  0.02514  0.01303  0.00410  0.00088
# 0.18    0.058160  0.02514  0.01303  0.00410  0.00088
# 0.19    0.058160  0.02514  0.01303  0.00410  0.00088

# %%
plt.figure(figsize=(12,6))
plt.plot(mesh_errors.loc[0.19],label = 'Mesh errors')
plt.xlabel('Number of mesh cells')
plt.plot(max_error.loc[0.19],label = 'Error with finest mesh')
plt.ylabel('Error of max velocity, m/s')
plt.title('Error calculation based on mesh refinement')
plt.legend();
plt.xticks([0, 1, 2,3,4], ['16k-8k','57k-16k','194k-57k', '460k-194k','656k-460k']);

# %%
norm2 = []
for i in range(0,len(files)):
    l2 = np.abs(max(plots[i])-max(analytical_solution))
    print('difference between max analitical solution and computational result', files[i],'is:',round (l2,8), 'm/s')
    norm2.append(l2)
# Out:
# difference between max analitical solution and computational result 8k_cells is: 0.02999876 m/s
# difference between max analitical solution and computational result 16k_cells is: 0.00318994 m/s
# difference between max analitical solution and computational result 57k_cells is: 0.01533999 m/s
# difference between max analitical solution and computational result 194k_cells is: 0.02428557 m/s
# difference between max analitical solution and computational result 460k_cells is: 0.02751006 m/s
# difference between max analitical solution and computational result 656k_cells is: 0.0283965 m/s
